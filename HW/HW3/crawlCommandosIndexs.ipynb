# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)

# %% [markdown]
# Code from HW2

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
from collections import defaultdict
import requests
import re
import json
import os
import pandas as pd
import math
from urllib.parse import urljoin, urlparse
import time


# Ensure NLTK resources are downloaded
print("Downloading NLTK resources...")
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
print("NLTK resources downloaded.\n")

# Function to extract and normalize links from a webpage
def get_links(url):
    print(f"Extracting links from: {url}")
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]
        # Normalize links to absolute URLs
        normalized_links = []
        for link in links:
            if link.startswith('/'):
                # Convert relative URL to absolute
                normalized_link = urljoin(url, link)
                normalized_links.append(normalized_link)
            elif link.startswith('http'):
                normalized_links.append(link)
            # Ignore other types of links (e.g., mailto:, javascript:)
        print(f"Found {len(normalized_links)} normalized links.\n")
        return normalized_links
    except Exception as e:
        print(f"Error extracting links from {url}: {e}\n")
        return []

# Text preprocessing functions
from nltk.corpus import stopwords

def remove_stop_words(text, isAlphaChecking=True):
    stop_words = set(stopwords.words('english'))
    if isAlphaChecking:
        words = [word for word in text if word.lower() not in stop_words and word.isalpha()]
    else:
        words = [word for word in text if word.lower() not in stop_words]
    return words

def trim_words(words):
    cleaned_words = [word.rstrip(",.\\/?!'\"") for word in words]
    return cleaned_words

def apply_stemming(words):
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in words]
    return stemmed_words

def apply_lemmatization(words):
    print("CHECK!")
    print(words[:20])
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    print(lemmatized_words[:20])
    return lemmatized_words

# Function to create index and collect search results
def create_index(url, max_pages=250):
    print("Starting to create index and collect search results...\n")
    index = defaultdict(dict)  # word -> {doc_id: term_frequency}
    visited = set()
    queue = [url]
    results = []  # To store search results with relevant fields
    pages_crawled = 0
    link_ids = {}  # link -> unique ID

    while queue and pages_crawled < max_pages:
        current_url = queue.pop(0)

        # Normalize the URL to avoid duplicates (e.g., remove trailing slash)
        parsed_url = urlparse(current_url)
        normalized_url = parsed_url.scheme + "://" + parsed_url.netloc + parsed_url.path.rstrip('/')

        if normalized_url in visited:
            print(f"Already visited: {normalized_url}\n")
            continue

        visited.add(normalized_url)
        pages_crawled += 1
        print(f"Crawling ({pages_crawled}/{max_pages}): {normalized_url}")

        try:
            session = requests.Session()
            session.max_redirects = 2
            response = session.get(normalized_url, allow_redirects=True, timeout=10)
            response.raise_for_status()

            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract title
            title = soup.title.string.strip() if soup.title else 'No Title'

            # Extract full text
            text = soup.get_text(separator=' ', strip=True)
            snippet = text[:200] + '...' if len(text) > 200 else text

            # Append to results
            results.append({
                'URL': normalized_url,
                'Title': title,
                'Snippet': snippet,
                'FullText': text  # Store full text for TF-IDF
            })

            print(f"Title Extracted: {title}")
            print(f"Snippet Extracted: {snippet}\n")

            # Process words for indexing
            words = remove_stop_words(text.split())
            words = trim_words(words)
            words = apply_stemming(words)  # or apply_lemmatization(words) based on preference

            print(f"Number of words after preprocessing: {len(words)}")

            for word in words:
                # Assign a unique ID to each document
                if normalized_url not in link_ids:
                    link_ids[normalized_url] = pages_crawled  # Assigning ID based on crawl order
                doc_id = link_ids[normalized_url]

                # Update term frequency for the word in the document
                if doc_id in index[word]:
                    index[word][doc_id] += 1
                else:
                    index[word][doc_id] = 1

            print(f"Indexed {len(words)} words for document ID {doc_id}.\n")

            # Get and enqueue links
            links = get_links(normalized_url)
            for link in links:
                # Only enqueue links that start with the base URL and haven't been visited
                if link.startswith(url) and link not in visited and 'services/certifications' not in link:
                    queue.append(link)
            print(f"Enqueued {len(links)} new links.\n")
        except requests.Timeout:
            print(f"Timeout: {normalized_url}\n")
            continue
        except requests.RequestException as e:
            print(f"RequestException: {e} for URL: {normalized_url}\n")
            continue

    # Create reverse mapping from doc_id to URL
    doc_id_to_url = {v: k for k, v in link_ids.items()}

    print(f"Finished crawling. Total pages crawled: {pages_crawled}")
    print(f"Total unique words indexed: {len(index)}\n")
    return index, results, doc_id_to_url

# Function to rank words based on total frequency across all documents
def create_ranked_words(index):
    print("Ranking words based on total frequency across all documents...")
    sorted_dict = {}
    for word, doc_dict in index.items():
        total_count = sum(doc_dict.values())
        sorted_dict[word] = total_count
    # Sort the dictionary by counts in descending order
    sorted_dict = dict(sorted(sorted_dict.items(), key=lambda item: item[1], reverse=True))
    ranked_dict = {}
    rank = 1
    for word, counter in sorted_dict.items():
        ranked_dict[word] = {'rank': rank, 'counter': counter}
        rank += 1
    print("Word ranking completed.\n")
    return ranked_dict

# Function to export search results to Excel
def export_search_results(search_results, filename='search_results.xlsx'):
    print(f"Exporting search results to {filename}...")
    df = pd.DataFrame(search_results)
    try:
      df.to_excel(filename, index=False)
      print(f"Search results have been exported to {filename}\n")
    except Exception as e:
      pass

# Function to export inverted index to Excel
def export_inverted_index(index, chosen_words, filename='inverted_index.xlsx'):
    print(f"Building inverted index for the top {len(chosen_words)} words and exporting to {filename}...")
    inverted_index_data = []
    for word in chosen_words:
        doc_dict = index[word]
        # Limit to first 20 documents if necessary
        limited_docs = dict(sorted(doc_dict.items()))
        for doc_id, count in limited_docs.items():
            inverted_index_data.append({'Word': word, 'Document_ID': doc_id, 'Term_Frequency': count})
    df_inverted = pd.DataFrame(inverted_index_data)
    df_inverted.to_excel(filename, index=False)
    print(f"Inverted index has been exported to {filename}\n")

def get_words_per_url(doc_id_to_url):
    updated_doc_id_to_url = {}
    for doc_id, url in doc_id_to_url.items():
      try:
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")
            text = soup.get_text()
            word_count = len(text.split())
      except Exception as e:
            print(f"Error accessing {url}: {e}")
            word_count = 0
      updated_doc_id_to_url[doc_id] = {"url": url, "totalwords": word_count}
    return updated_doc_id_to_url

def create_term_doc_excel_for_all_terms(index, doc_id_to_url, file_path="term_doc_appearance_all_terms.xlsx"):
    # Extract all terms from the index
    all_terms = sorted(index.keys())

    # Extract all unique document IDs for consistent column ordering
    all_doc_ids = sorted({doc_id for term_docs in index.values() for doc_id in term_docs})

    # Map document IDs to URLs for column headers
    urls = [doc_id_to_url.get(doc_id, f"Doc {doc_id}") for doc_id in all_doc_ids]

    # Prepare data for the DataFrame
    data = {"term/doc": []}
    for url in urls:
        data[url] = []

    # Populate term frequencies for each term
    for term in all_terms:
        data["term/doc"].append(term)
        for doc_id in all_doc_ids:
            # Get the frequency of the term in the document, or 0 if not present
            data[doc_id_to_url.get(doc_id, f"Doc {doc_id}")].append(index[term].get(doc_id, 0))

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Save DataFrame to Excel
    df.to_excel(file_path, index=False)
    return

def create_term_doc_excel_with_query(index, doc_id_to_url, query, file_path="term_doc_appearance.xlsx"):
    # Preprocess the query: remove stop words, apply stemming
    stop_words = set(stopwords.words("english"))
    stemmer = PorterStemmer()

    # Tokenize query, remove stop words, and apply stemming
    query_terms = query.split()
    processed_query_terms = [
        stemmer.stem(word.lower())
        for word in query_terms
        if word.lower() not in stop_words and word.isalpha()
    ]

    # Extract relevant terms (only those in the index)
    relevant_terms = [term for term in processed_query_terms if term in index]

    # Extract all unique document IDs for consistent column ordering
    all_doc_ids = sorted({doc_id for term_docs in index.values() for doc_id in term_docs})

    updated_doc_id_to_url = get_words_per_url(doc_id_to_url)
    # print(len(updated_doc_id_to_url))
    # print(updated_doc_id_to_url.get(1))
    # Map document IDs to URLs for column headers
    urls = [doc_id_to_url.get(doc_id, f"Doc {doc_id}") for doc_id in all_doc_ids]
    # print(urls)
    # Prepare data for the DataFrame
    data = {"term/doc": []}
    for url in urls:
        data[url] = []

    # Populate term frequencies for each relevant term
    for term in relevant_terms:
        data["term/doc"].append(term)
        for doc_id in all_doc_ids:
            data[doc_id_to_url.get(doc_id, f"Doc {doc_id}")].append(index[term].get(doc_id, 0))
            # print(data)

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Save DataFrame to Excel
    df.to_excel(file_path, index=False)
    return

# Main Execution

# TODO:
#   remove 16 word limit for inverted index and calculate for all documents instead of 20
#   after retrieving the results and calculating the inverted index run each query against the results to get the search results.

if __name__ == "__main__":
    start = time.time()
    website_url = 'https://www.who.int'
    query = "'which medicine is used for covid 19'"
    # ============================
    # 1. Creating the Index and Collecting Results
    # ============================

    max_pages_to_crawl = 30
    index, search_results, doc_id_to_url = create_index(website_url, max_pages=max_pages_to_crawl)

    # Create ranked words
    ranked_words = create_ranked_words(index)
    chosen_words = list(ranked_words.keys())#[:15]   extract top 15 keywords
    print(f"Chosen Words for Inverted Index: {chosen_words}\n")

    # ============================
    # 2. Export Search Results to Excel
    # ============================

    export_search_results(search_results, filename='search_results.xlsx')

    # ============================
    # 3. Build and Export Inverted Index
    # ============================
    export_inverted_index(index, chosen_words, filename='inverted_index.xlsx')
    create_term_doc_excel_with_query(index, doc_id_to_url, query)
    create_term_doc_excel_for_all_terms(index, doc_id_to_url)
    end = time.time()
    print(end - start)

# %%
print()

# %% [markdown]
# crawling and indexing without Excel files

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
from collections import defaultdict
import requests
import re
import json
import os
import pandas as pd
import math
from urllib.parse import urljoin, urlparse
import time

# Ensure NLTK resources are downloaded
print("Downloading NLTK resources...")
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
print("NLTK resources downloaded.\n")

from nltk.corpus import stopwords

# Text preprocessing functions
def remove_stop_words(text_tokens):
    """Remove standard English stopwords and keep only alphabetic tokens."""
    stop_words = set(stopwords.words('english'))
    words = [word for word in text_tokens if word.lower() not in stop_words and word.isalpha()]
    return words

def trim_words(words):
    """Trim punctuation from ends of words."""
    cleaned_words = [word.rstrip(",.\\/?!'\"") for word in words]
    return cleaned_words

def apply_stemming(words):
    """Apply Porter stemming to tokens."""
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word.lower()) for word in words]
    return stemmed_words

def apply_lemmatization(words):
    """Apply lemmatization to tokens."""
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word.lower()) for word in words]
    return lemmatized_words

def get_links(url):
    """
    Extract all absolute (normalized) links from a webpage.
    Only returns http/https links.
    """
    print(f"Extracting links from: {url}")
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [link.get('href') for link in soup.find_all('a', href=True)]

        normalized_links = []
        for link in links:
            if link.startswith('/'):
                # Convert relative URL to absolute
                normalized_link = urljoin(url, link)
                normalized_links.append(normalized_link)
            elif link.startswith('http'):
                normalized_links.append(link)
        print(f"Found {len(normalized_links)} normalized links.\n")
        return normalized_links
    except Exception as e:
        print(f"Error extracting links from {url}: {e}\n")
        return []

def create_index(start_url, max_pages=50):
    """
    Crawl up to `max_pages` starting from `start_url`.
    Build:
      - index: word -> {doc_id: term_frequency_in_doc}
      - results: list of metadata for each page (URL, Title, Snippet, FullText)
      - doc_id_to_url: map doc_id -> URL
      - doc_length: map doc_id -> total number of preprocessed words (for TF normalization)
    """

    # Terms to exclude from any URL
    excluded_terms = [
        "/mega-menu",
        "/services/certifications",
        "/login",
        "/subscribe",
        "/facebook",
        "/twitter",
        "/instagram",
        "/youtube",
        "/search?",
        "/draft",
        "/template",
        "/newsletters",
        "/maldives",
        "/footer",
        "/southeastasia",
        "/south-east-asia",
        "/europe",
        "/health-topics",
        "/about-us"
    ]


    index = defaultdict(dict)
    visited = set()
    queue = [start_url]
    results = []
    pages_crawled = 0
    link_ids = {}
    doc_length = {}

    while queue and pages_crawled < max_pages:
        current_url = queue.pop(0)

        # Normalize the URL
        parsed_url = urlparse(current_url)
        normalized_url = parsed_url.scheme + "://" + parsed_url.netloc + parsed_url.path.rstrip('/')

        if normalized_url in visited:
            continue

        visited.add(normalized_url)
        pages_crawled += 1
        print(f"Crawling ({pages_crawled}/{max_pages}): {normalized_url}")

        try:
            session = requests.Session()
            session.max_redirects = 2
            response = session.get(normalized_url, allow_redirects=True, timeout=10)
            response.raise_for_status()

            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract title
            title = soup.title.string.strip() if soup.title else 'No Title'

            # Extract text for indexing
            text = soup.get_text(separator=' ', strip=True)
            snippet = text[:200] + '...' if len(text) > 200 else text

            # Assign doc_id for this page
            doc_id = pages_crawled
            link_ids[normalized_url] = doc_id

            # Store metadata
            results.append({
                'URL': normalized_url,
                'Title': title,
                'Snippet': snippet,
                'FullText': text
            })

            print(f"Title Extracted: {title}")
            print(f"Snippet Extracted: {snippet[:100]}\n")

            # Preprocess tokens (stopword removal, stemming, etc.)
            raw_tokens = text.split()
            cleaned_tokens = remove_stop_words(raw_tokens)
            cleaned_tokens = trim_words(cleaned_tokens)
            cleaned_tokens = apply_stemming(cleaned_tokens)

            doc_length[doc_id] = len(cleaned_tokens)
            print(f"Number of tokens after preprocessing: {doc_length[doc_id]}")

            # Update inverted index
            for token in cleaned_tokens:
                index[token].setdefault(doc_id, 0)
                index[token][doc_id] += 1

            print(f"Indexed {len(cleaned_tokens)} tokens for document ID {doc_id}.\n")

            # Extract links and enqueue children
            extracted_links = get_links(normalized_url)
            for link in extracted_links:
                # Skip excluded terms
                if any(excluded in link for excluded in excluded_terms):
                    continue

                # You can also restrict to the base domain if desired:
                if link.startswith(start_url) and link not in visited:
                    queue.append(link)

        except requests.Timeout:
            print(f"Timeout: {normalized_url}\n")
            continue
        except requests.RequestException as e:
            print(f"RequestException: {e} for URL: {normalized_url}\n")
            continue

    doc_id_to_url = {v: k for k, v in link_ids.items()}

    print(f"Finished crawling. Total pages crawled: {pages_crawled}")
    print(f"Total unique words indexed: {len(index)}\n")

    return index, results, doc_id_to_url, doc_length


def compute_idf(index, total_docs):
    """
    Compute Inverse Document Frequency for each term in the index.
    IDF(term) = log( total_docs / (df + 1) ) + 1
      - 'df' is the number of docs containing the term
    Returns a dictionary: { term: idf_value }
    """
    idf_dict = {}
    for term, posting_dict in index.items():
        df = len(posting_dict)  # number of docs that contain this term
        # Add 1 to avoid division by zero if df=0
        idf_value = math.log((total_docs / (df + 1)), 10) + 1
        idf_dict[term] = idf_value
    return idf_dict


def search(query, index, idf_dict, doc_length, doc_id_to_url, search_results, top_k=10):
    """
    Given a query string, rank documents by TF-IDF score.
    Return the top_k results as a list of dicts: { 'doc_id', 'score', 'URL', 'Title', 'Snippet' }.
    """

    # --- Preprocess the query ---
    stop_words = set(stopwords.words("english"))
    stemmer = PorterStemmer()

    raw_query_tokens = query.split()
    query_tokens = [
        stemmer.stem(w.lower()) for w in raw_query_tokens
        if w.lower() not in stop_words and w.isalpha()
    ]

    if not query_tokens:
        print("No valid tokens in the query after preprocessing.")
        return []

    # --- Accumulate scores ---
    scores = defaultdict(float)  # doc_id -> score

    # For each token in the query, update the TF-IDF score for each doc that has it
    for token in query_tokens:
        if token not in index:
            continue  # Token not in any doc
        posting_list = index[token]
        for doc_id, freq in posting_list.items():
            # TF = frequency_in_doc / doc_length
            tf = freq / doc_length[doc_id]
            # IDF for the token
            idf = idf_dict[token]
            # Accumulate
            scores[doc_id] += (tf * idf)

    # --- Sort docs by score descending ---
    # We only want docs that have a nonzero score
    ranked_doc_ids = sorted(scores.items(), key=lambda x: x[1], reverse=True)

    # --- Build final results ---
    # Convert doc_id -> metadata (title, snippet, etc.)
    result_docs = []
    for doc_id, score in ranked_doc_ids[:top_k]:
        # Find the corresponding entry in search_results
        # or build from doc_id_to_url
        url = doc_id_to_url[doc_id]
        # Attempt to get the snippet/title from search_results
        # We can do a quick lookup:
        metadata = next((d for d in search_results if d['URL'] == url), None)
        if metadata:
            result_docs.append({
                'doc_id': doc_id,
                'score': score,
                'URL': url,
                'Title': metadata['Title'],
                'Snippet': metadata['Snippet'],
            })
        else:
            result_docs.append({
                'doc_id': doc_id,
                'score': score,
                'URL': url,
                'Title': "No Title",
                'Snippet': "",
            })

    return result_docs

def create_ranked_words(index):
    """
    Return a dict sorted by total frequency across all docs
    word -> { 'rank': rank, 'counter': total_frequency_across_docs }
    """
    print("Ranking words based on total frequency across all documents...")
    sorted_dict = {}
    for word, doc_dict in index.items():
        total_count = sum(doc_dict.values())
        sorted_dict[word] = total_count

    sorted_dict = dict(sorted(sorted_dict.items(), key=lambda item: item[1], reverse=True))

    ranked_dict = {}
    rank = 1
    for word, counter in sorted_dict.items():
        ranked_dict[word] = {'rank': rank, 'counter': counter}
        rank += 1

    print("Word ranking completed.\n")
    return ranked_dict

def export_search_results(search_results, filename='search_results.xlsx'):
    print(f"Exporting search results to {filename}...")
    df = pd.DataFrame(search_results)
    try:
        df.to_excel(filename, index=False)
        print(f"Search results have been exported to {filename}\n")
    except Exception as e:
        print(f"Error exporting search results: {e}")

def export_inverted_index(index, chosen_words, filename='inverted_index.xlsx'):
    print(f"Building inverted index for the top {len(chosen_words)} words and exporting to {filename}...")
    inverted_index_data = []
    for word in chosen_words:
        doc_dict = index[word]
        # For large corpora, you might limit docs displayed
        for doc_id, count in doc_dict.items():
            inverted_index_data.append({'Word': word, 'Document_ID': doc_id, 'Term_Frequency': count})
    df_inverted = pd.DataFrame(inverted_index_data)
    try:
        df_inverted.to_excel(filename, index=False)
        print(f"Inverted index has been exported to {filename}\n")
    except Exception as e:
        print(f"Error exporting inverted index: {e}")

# Optional helpers to export term-doc matrices, etc.
def create_term_doc_excel_with_query(index, doc_id_to_url, query, file_path="term_doc_appearance_query.xlsx"):
    """
    Creates an Excel file listing term frequencies in each doc for terms in the given query.
    Rows = query terms
    Columns = document URLs
    """

    stop_words = set(nltk.corpus.stopwords.words("english"))
    stemmer = PorterStemmer()

    # --- 1. Preprocess the query ---
    raw_query_tokens = query.split()
    processed_query_terms = [
        stemmer.stem(word.lower())
        for word in raw_query_tokens
        if word.lower() not in stop_words and word.isalpha()
    ]

    # Keep only the terms that actually appear in our index
    relevant_terms = [term for term in processed_query_terms if term in index]
    if not relevant_terms:
        print("No relevant terms from the query found in the index.")
        return

    # --- 2. Identify all doc IDs (so we can create columns) ---
    all_doc_ids = sorted({doc_id for posting in index.values() for doc_id in posting})

    # --- 3. Prepare data dictionary for DataFrame ---
    # We'll have one row per query term, plus one column "Term"
    data = {"Term": relevant_terms}

    # Create an empty list for each doc's column
    for doc_id in all_doc_ids:
        doc_url = doc_id_to_url.get(doc_id, f"Doc {doc_id}")
        data[doc_url] = []  # Each column is initially empty

    # --- 4. Fill in frequencies for each (term, doc) pair ---
    for term in relevant_terms:
        for doc_id in all_doc_ids:
            freq = index[term].get(doc_id, 0)
            doc_url = doc_id_to_url.get(doc_id, f"Doc {doc_id}")
            data[doc_url].append(freq)

    # --- 5. Create and export DataFrame ---
    df = pd.DataFrame(data)
    try:
        df.to_excel(file_path, index=False)
        print(f"Term-doc appearance for the query saved to '{file_path}'.")
    except Exception as e:
        print(f"Error saving term-doc appearance: {e}")

def create_term_doc_excel_for_all_terms(index, doc_id_to_url, file_path="term_doc_appearance_all_terms.xlsx"):
    """Creates an Excel file listing term frequencies for all terms in each doc."""
    all_terms = sorted(index.keys())
    all_doc_ids = sorted({doc_id for term_docs in index.values() for doc_id in term_docs})
    data = {"term/doc": []}
    urls = [doc_id_to_url.get(doc_id, f"Doc {doc_id}") for doc_id in all_doc_ids]

    for url in urls:
        data[url] = []

    for term in all_terms:
        data["term/doc"].append(term)
        for doc_id_idx, doc_id in enumerate(all_doc_ids):
            col_url = urls[doc_id_idx]
            tf = index[term].get(doc_id, 0)
            data[col_url].append(tf)

    df = pd.DataFrame(data)
    try:
        df.to_excel(file_path, index=False)
        print(f"All term-doc appearances saved to {file_path}")
    except Exception as e:
        print(f"Error saving all terms doc matrix: {e}")


def pretty_print_results(query, results):
    """
    Display search results in a neat table using pandas.
    Each row: Rank, Score, Title, URL, Snippet
    """
    # Prepare a list of dict rows to feed into a DataFrame
    rows = []
    for rank, item in enumerate(results, start=1):
        rows.append({
            'Rank': rank,
            'Score': round(item['score'], 4),
            'Title': item['Title'],
            'URL': item['URL'],
            'Snippet': item['Snippet'][:50] + "..."  # Just show first ~50 chars
        })
    # Create DataFrame
    df = pd.DataFrame(rows, columns=['Rank', 'Score', 'Title', 'URL', 'Snippet'])
    print(f"\n===== Results for Query: \"{query}\" =====\n")
    print(df.to_string(index=False))
    print("\n")

# =========================
# Main Execution Example
# =========================
if __name__ == "__main__":
    start_time = time.time()

    # 1. Crawl & build index
    website_url = 'https://www.who.int'
    max_pages_to_crawl = 3000
    index, search_results, doc_id_to_url, doc_length = create_index(website_url, max_pages=max_pages_to_crawl)

    # 2. Compute IDF for the corpus
    total_docs = len(doc_id_to_url)
    idf_dict = compute_idf(index, total_docs)

    # 3. Export search results
    export_search_results(search_results, filename='search_results.xlsx')

    # 4. Create a word frequency ranking
    ranked_words = create_ranked_words(index)
    # Let's pick some subset if you want
    chosen_words = list(ranked_words.keys())[:15]
    export_inverted_index(index, chosen_words, filename='inverted_index.xlsx')

    # Example queries
    queries = [
        'Types of COVID-19 Treatment',
        "guidelines on antibiotic resistance",
        "mental health resources during emergencies"
    ]

    for q in queries:
        # top_k can be adjusted to show however many results you want
        top_k = 20
        results_for_query = search(
            q,
            index,
            idf_dict,
            doc_length,
            doc_id_to_url,
            search_results,
            top_k=top_k
        )
        pretty_print_results(q, results_for_query)

    # [Optional] Export full term-doc matrix
    create_term_doc_excel_for_all_terms(index, doc_id_to_url, file_path="term_doc_appearance_all_terms.xlsx")

    end_time = time.time()
    print(f"Done! Elapsed time: {end_time - start_time:.2f} seconds.")
# Out:
# Streaming output truncated to the last 5000 lines.
# %����
# 1 0 obj
# < >/Metadata 2293 0 R/ViewerPreferences 2294 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 3058
# Indexed 3058 tokens for document ID 2444.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200303-sitrep-43-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2445/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200302-sitrep-42-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 2149 0 R/ViewerPreferences 2150 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2812
# Indexed 2812 tokens for document ID 2445.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200302-sitrep-42-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2446/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200301-sitrep-41-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1819 0 R/ViewerPreferences 1820 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2479
# Indexed 2479 tokens for document ID 2446.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200301-sitrep-41-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2447/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200229-sitrep-40-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1770 0 R/ViewerPreferences 1771 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2482
# Indexed 2482 tokens for document ID 2447.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200229-sitrep-40-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2448/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200228-sitrep-39-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1853 0 R/ViewerPreferences 1854 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2466
# Indexed 2466 tokens for document ID 2448.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200228-sitrep-39-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2449/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200227-sitrep-38-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1900 0 R/ViewerPreferences 1901 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2611
# Indexed 2611 tokens for document ID 2449.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200227-sitrep-38-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2450/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200226-sitrep-37-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1678 0 R/ViewerPreferences 1679 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2288
# Indexed 2288 tokens for document ID 2450.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200226-sitrep-37-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2451/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200225-sitrep-36-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1615 0 R/ViewerPreferences 1616 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2326
# Indexed 2326 tokens for document ID 2451.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200225-sitrep-36-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2452/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200224-sitrep-35-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1590 0 R/ViewerPreferences 1591 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2372
# Indexed 2372 tokens for document ID 2452.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200224-sitrep-35-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2453/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200223-sitrep-34-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1500 0 R/ViewerPreferences 1501 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2104
# Indexed 2104 tokens for document ID 2453.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200223-sitrep-34-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2454/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200222-sitrep-33-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1690 0 R/ViewerPreferences 1691 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2302
# Indexed 2302 tokens for document ID 2454.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200222-sitrep-33-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2455/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200221-sitrep-32-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1532 0 R/ViewerPreferences 1533 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2192
# Indexed 2192 tokens for document ID 2455.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200221-sitrep-32-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2456/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200220-sitrep-31-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1496 0 R/ViewerPreferences 1497 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2168
# Indexed 2168 tokens for document ID 2456.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200220-sitrep-31-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2457/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200219-sitrep-30-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1661 0 R/ViewerPreferences 1662 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2433
# Indexed 2433 tokens for document ID 2457.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200219-sitrep-30-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2458/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200218-sitrep-29-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1434 0 R/ViewerPreferences 1435 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2067
# Indexed 2067 tokens for document ID 2458.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200218-sitrep-29-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2459/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200217-sitrep-28-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1462 0 R/ViewerPreferences 1463 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2245
# Indexed 2245 tokens for document ID 2459.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200217-sitrep-28-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2460/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200216-sitrep-27-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1770 0 R/ViewerPreferences 1771 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2390
# Indexed 2390 tokens for document ID 2460.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200216-sitrep-27-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2461/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200215-sitrep-26-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1714 0 R/ViewerPreferences 1715 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2349
# Indexed 2349 tokens for document ID 2461.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200215-sitrep-26-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2462/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200214-sitrep-25-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1691 0 R/ViewerPreferences 1692 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2289
# Indexed 2289 tokens for document ID 2462.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200214-sitrep-25-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2463/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200213-sitrep-24-covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1232 0 R/ViewerPreferences 1233 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1918
# Indexed 1918 tokens for document ID 2463.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200213-sitrep-24-covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2464/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200212-sitrep-23-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1289 0 R/ViewerPreferences 1290 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 2034
# Indexed 2034 tokens for document ID 2464.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200212-sitrep-23-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2465/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200211-sitrep-22-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1058 0 R/ViewerPreferences 1059 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1734
# Indexed 1734 tokens for document ID 2465.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200211-sitrep-22-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2466/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200210-sitrep-21-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1005 0 R/ViewerPreferences 1006 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1630
# Indexed 1630 tokens for document ID 2466.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200210-sitrep-21-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2467/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200209-sitrep-20-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1051 0 R/ViewerPreferences 1052 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1740
# Indexed 1740 tokens for document ID 2467.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200209-sitrep-20-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2468/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200208-sitrep-19-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1053 0 R/ViewerPreferences 1054 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1737
# Indexed 1737 tokens for document ID 2468.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200208-sitrep-19-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2469/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200207-sitrep-18-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1023 0 R/ViewerPreferences 1024 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1645
# Indexed 1645 tokens for document ID 2469.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200207-sitrep-18-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2470/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200206-sitrep-17-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1086 0 R/ViewerPreferences 1087 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1771
# Indexed 1771 tokens for document ID 2470.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200206-sitrep-17-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2471/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200205-sitrep-16-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1089 0 R/ViewerPreferences 1090 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1740
# Indexed 1740 tokens for document ID 2471.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200205-sitrep-16-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2472/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200204-sitrep-15-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 969 0 R/ViewerPreferences 970 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1470
# Indexed 1470 tokens for document ID 2472.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200204-sitrep-15-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2473/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200203-sitrep-14-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 1044 0 R/ViewerPreferences 1045 0 R>>
# endobj
# 2 0 obj
# < >
#
#
# Number of tokens after preprocessing: 1635
# Indexed 1635 tokens for document ID 2473.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200203-sitrep-14-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2474/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200202-sitrep-13-ncov-v3.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 858 0 R/ViewerPreferences 859 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1416
# Indexed 1416 tokens for document ID 2474.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200202-sitrep-13-ncov-v3.pdf
# Found 0 normalized links.
#
# Crawling (2475/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200201-sitrep-12-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 872 0 R/ViewerPreferences 873 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1381
# Indexed 1381 tokens for document ID 2475.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200201-sitrep-12-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2476/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200131-sitrep-11-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 712 0 R/ViewerPreferences 713 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1255
# Indexed 1255 tokens for document ID 2476.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200131-sitrep-11-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2477/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200130-sitrep-10-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 824 0 R/ViewerPreferences 825 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1418
# Indexed 1418 tokens for document ID 2477.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200130-sitrep-10-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2478/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200129-sitrep-9-ncov-v2.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 713 0 R/ViewerPreferences 714 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1266
# Indexed 1266 tokens for document ID 2478.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200129-sitrep-9-ncov-v2.pdf
# Found 0 normalized links.
#
# Crawling (2479/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200128-sitrep-8-ncov-cleared.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 758 0 R/ViewerPreferences 759 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 522
# Indexed 522 tokens for document ID 2479.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200128-sitrep-8-ncov-cleared.pdf
# Found 0 normalized links.
#
# Crawling (2480/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200127-sitrep-7-2019--ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 666 0 R/ViewerPreferences 667 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1234
# Indexed 1234 tokens for document ID 2480.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200127-sitrep-7-2019--ncov.pdf
# Found 0 normalized links.
#
# Crawling (2481/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200126-sitrep-6-2019--ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 671 0 R/ViewerPreferences 672 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1396
# Indexed 1396 tokens for document ID 2481.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200126-sitrep-6-2019--ncov.pdf
# Found 0 normalized links.
#
# Crawling (2482/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200125-sitrep-5-2019-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 602 0 R/ViewerPreferences 603 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1319
# Indexed 1319 tokens for document ID 2482.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200125-sitrep-5-2019-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2483/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200124-sitrep-4-2019-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 668 0 R/ViewerPreferences 669 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1302
# Indexed 1302 tokens for document ID 2483.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200124-sitrep-4-2019-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2484/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200123-sitrep-3-2019-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 627 0 R/ViewerPreferences 628 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1250
# Indexed 1250 tokens for document ID 2484.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200123-sitrep-3-2019-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2485/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200122-sitrep-2-2019-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 681 0 R/ViewerPreferences 682 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 1248
# Indexed 1248 tokens for document ID 2485.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200122-sitrep-2-2019-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2486/3000): https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200121-sitrep-1-2019-ncov.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 469 0 R/ViewerPreferences 470 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 994
# Indexed 994 tokens for document ID 2486.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/situation-reports/20200121-sitrep-1-2019-ncov.pdf
# Found 0 normalized links.
#
# Crawling (2487/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---19-september-2024
# Title Extracted: WHO press conference on global health issues – 19 September 2024
# Snippet Extracted: WHO press conference on global health issues – 19 September 2024 Skip to main content Global Regions
#
# Number of tokens after preprocessing: 340
# Indexed 340 tokens for document ID 2487.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---19-september-2024
# Found 214 normalized links.
#
# Crawling (2488/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---4-september-2024
# Title Extracted: WHO press conference on global health issues – 4 September 2024
# Snippet Extracted: WHO press conference on global health issues – 4 September 2024 Skip to main content Global Regions
#
# Number of tokens after preprocessing: 340
# Indexed 340 tokens for document ID 2488.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---4-september-2024
# Found 214 normalized links.
#
# Crawling (2489/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---30-august-2024
# Title Extracted: WHO press conference on global health issues – 30 August 2024
# Snippet Extracted: WHO press conference on global health issues – 30 August 2024 Skip to main content Global Regions WH
#
# Number of tokens after preprocessing: 340
# Indexed 340 tokens for document ID 2489.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---30-august-2024
# Found 214 normalized links.
#
# Crawling (2490/3000): https://www.who.int/multi-media/details/who-press-conference-following-the-ihr-emergency-committee-meeting-on-the-upsurge-of-mpox---14-august-2024
# Title Extracted: WHO press conference following the IHR Emergency Committee meeting on the upsurge of mpox – 14 August 2024
# Snippet Extracted: WHO press conference following the IHR Emergency Committee meeting on the upsurge of mpox – 14 Augus
#
# Number of tokens after preprocessing: 352
# Indexed 352 tokens for document ID 2490.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-following-the-ihr-emergency-committee-meeting-on-the-upsurge-of-mpox---14-august-2024
# Found 214 normalized links.
#
# Crawling (2491/3000): https://www.who.int/news-room/feature-stories/detail/how-do-vaccines-work
# Title Extracted: How do vaccines work?
# Snippet Extracted: How do vaccines work? Skip to main content Global Regions WHO Regional websites Africa Americas Sout
#
# Number of tokens after preprocessing: 711
# Indexed 711 tokens for document ID 2491.
#
# Extracting links from: https://www.who.int/news-room/feature-stories/detail/how-do-vaccines-work
# Found 228 normalized links.
#
# Crawling (2492/3000): https://www.who.int/westernpacific/emergencies/covid-19/news-covid-19
# Title Extracted: Latest news
# Snippet Extracted: Latest news Skip to main content Global Regions WHO Regional websites Africa Americas South-East Asi
#
# Number of tokens after preprocessing: 3230
# Indexed 3230 tokens for document ID 2492.
#
# Extracting links from: https://www.who.int/westernpacific/emergencies/covid-19/news-covid-19
# Found 498 normalized links.
#
# Crawling (2493/3000): https://www.who.int/news-room/feature-stories/detail/responsible-media-reporting-on-covid-19-vaccines
# Title Extracted: Tips for professional reporting on COVID-19 vaccines
# Snippet Extracted: Tips for professional reporting on COVID-19 vaccines Skip to main content Global Regions WHO Regiona
#
# Number of tokens after preprocessing: 692
# Indexed 692 tokens for document ID 2493.
#
# Extracting links from: https://www.who.int/news-room/feature-stories/detail/responsible-media-reporting-on-covid-19-vaccines
# Found 224 normalized links.
#
# Crawling (2494/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---7-august-2024
# Title Extracted: WHO press conference on global health issues – 7 August 2024
# Snippet Extracted: WHO press conference on global health issues – 7 August 2024 Skip to main content Global Regions WHO
#
# Number of tokens after preprocessing: 340
# Indexed 340 tokens for document ID 2494.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---7-august-2024
# Found 214 normalized links.
#
# Crawling (2495/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues-with-dr-tedros-11-july-2024
# Title Extracted: WHO press conference on global health issues with Dr Tedros – 11 July 2024
# Snippet Extracted: WHO press conference on global health issues with Dr Tedros – 11 July 2024 Skip to main content Glob
#
# Number of tokens after preprocessing: 346
# Indexed 346 tokens for document ID 2495.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues-with-dr-tedros-11-july-2024
# Found 214 normalized links.
#
# Crawling (2496/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---31-january-2024
# Title Extracted: WHO press conference on global health issues – 31 January 2024
# Snippet Extracted: WHO press conference on global health issues – 31 January 2024 Skip to main content Global Regions W
#
# Number of tokens after preprocessing: 3623
# Indexed 3623 tokens for document ID 2496.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues---31-january-2024
# Found 215 normalized links.
#
# Crawling (2497/3000): https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues-10-january-2024
# Title Extracted: WHO press conference on global health issues – 10 January 2024
# Snippet Extracted: WHO press conference on global health issues – 10 January 2024 Skip to main content Global Regions W
#
# Number of tokens after preprocessing: 3118
# Indexed 3118 tokens for document ID 2497.
#
# Extracting links from: https://www.who.int/multi-media/details/who-press-conference-on-global-health-issues-10-january-2024
# Found 215 normalized links.
#
# Crawling (2498/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/1
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content World Health Organization Global Regions World Health
#
# Number of tokens after preprocessing: 1109
# Indexed 1109 tokens for document ID 2498.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/1
# Found 333 normalized links.
#
# Crawling (2499/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/2
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1102
# Indexed 1102 tokens for document ID 2499.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/2
# Found 333 normalized links.
#
# Crawling (2500/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/3
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1105
# Indexed 1105 tokens for document ID 2500.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/3
# Found 333 normalized links.
#
# Crawling (2501/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/4
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1110
# Indexed 1110 tokens for document ID 2501.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/4
# Found 333 normalized links.
#
# Crawling (2502/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/5
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1110
# Indexed 1110 tokens for document ID 2502.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/5
# Found 333 normalized links.
#
# Crawling (2503/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/6
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content World Health Organization Global Regions World Health
#
# Number of tokens after preprocessing: 1116
# Indexed 1116 tokens for document ID 2503.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/6
# Found 333 normalized links.
#
# Crawling (2504/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/7
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1099
# Indexed 1099 tokens for document ID 2504.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/7
# Found 333 normalized links.
#
# Crawling (2505/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/8
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1097
# Indexed 1097 tokens for document ID 2505.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/8
# Found 333 normalized links.
#
# Crawling (2506/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/9
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1094
# Indexed 1094 tokens for document ID 2506.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/9
# Found 333 normalized links.
#
# Crawling (2507/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/10
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content Global Regions WHO Regional websites Africa Americas S
#
# Number of tokens after preprocessing: 1098
# Indexed 1098 tokens for document ID 2507.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/10
# Found 333 normalized links.
#
# Crawling (2508/3000): https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/11
# Title Extracted: Previous press briefings
# Snippet Extracted: Previous press briefings Skip to main content World Health Organization Global Regions World Health
#
# Number of tokens after preprocessing: 1111
# Indexed 1111 tokens for document ID 2508.
#
# Extracting links from: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/press-briefings/previous/11
# Found 326 normalized links.
#
# Crawling (2509/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---28-septemberd432ff84b4d745bfa96ed402d1dbc480.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# �=4{�}����sٿ���z$q�BCW�mI�?ɲ���w�4`�J
#
# Number of tokens after preprocessing: 362
# Indexed 362 tokens for document ID 2509.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---28-septemberd432ff84b4d745bfa96ed402d1dbc480.pdf
# Found 0 normalized links.
#
# Crawling (2510/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-25th-september.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# 4��y@`v/��)UIn�[�����-��>}�T�=�vߔVz�1*�
#
# Number of tokens after preprocessing: 397
# Indexed 397 tokens for document ID 2510.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-25th-september.pdf
# Found 0 normalized links.
#
# Crawling (2511/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/joint-covid-19-virtual-press-conference---21-september.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# L��%��RI��i-3c[ҫz�k�G�{ �����V��
#
# Number of tokens after preprocessing: 496
# Indexed 496 tokens for document ID 2511.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/joint-covid-19-virtual-press-conference---21-september.pdf
# Found 0 normalized links.
#
# Crawling (2512/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/joint-covid-19-virtual-press-conference-final-18-september.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 360 0 R/ViewerPreferences 361 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 602
# Indexed 602 tokens for document ID 2512.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/joint-covid-19-virtual-press-conference-final-18-september.pdf
# Found 0 normalized links.
#
# Crawling (2513/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-17sep2020.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >
# endobj
# 2 0 obj
# < >
# endobj
# 3 0 obj
# < >/ExtGState< >/Font< >/ProcS
#
# Number of tokens after preprocessing: 259
# Indexed 259 tokens for document ID 2513.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-17sep2020.pdf
# Found 0 normalized links.
#
# Crawling (2514/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-15sep2020.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >
# endobj
# 2 0 obj
# < >
# endobj
# 3 0 obj
# < >/ExtGState< >/Font< >/ProcS
#
# Number of tokens after preprocessing: 248
# Indexed 248 tokens for document ID 2514.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-15sep2020.pdf
# Found 0 normalized links.
#
# Crawling (2515/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-final-10sep2020.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 239 0 R/ViewerPreferences 240 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 464
# Indexed 464 tokens for document ID 2515.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/who-audio-emergencies-coronavirus-press-conference-final-10sep2020.pdf
# Found 0 normalized links.
#
# Crawling (2516/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---7-september-corrects-name.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 396 0 R/ViewerPreferences 397 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 666
# Indexed 666 tokens for document ID 2516.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---7-september-corrects-name.pdf
# Found 0 normalized links.
#
# Crawling (2517/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-4-september.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˎ�6��+�._�z���$��tQtu�
# �s7��R�$���t�[��8$��;P��ޕV�
#
# Number of tokens after preprocessing: 411
# Indexed 411 tokens for document ID 2517.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-4-september.pdf
# Found 0 normalized links.
#
# Crawling (2518/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---31-august.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 366 0 R/ViewerPreferences 367 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 207
# Indexed 207 tokens for document ID 2518.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---31-august.pdf
# Found 0 normalized links.
#
# Crawling (2519/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---27-august.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��XK��6��Wh]H�f$Y2�@��@�;�t�n˹����C��D�O�\n|"yF3�|�P�	�?�c�=
#
# Number of tokens after preprocessing: 364
# Indexed 364 tokens for document ID 2519.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---27-august.pdf
# Found 0 normalized links.
#
# Crawling (2520/3000): https://www.who.int/docs/default-source/coronaviruse/media-advisory-covid-19-virtual-press-conference-24-august-2020.pdf
# Title Extracted: No Title
# %����
#
# < >/Filter/FlateDecode/ID[ <940B3D99CA8
#
# Number of tokens after preprocessing: 207
# Indexed 207 tokens for document ID 2520.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/media-advisory-covid-19-virtual-press-conference-24-august-2020.pdf
# Found 0 normalized links.
#
# Crawling (2521/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---21-august.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# ����z(z��l��K�~IQR�Ē��MƒE=�������O��
#
# Number of tokens after preprocessing: 340
# Indexed 340 tokens for document ID 2521.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---21-august.pdf
# Found 0 normalized links.
#
# Crawling (2522/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---18-august.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# r�v�=��~j!%�MR$����W�6���O�Ԩt\
#
# Number of tokens after preprocessing: 377
# Indexed 377 tokens for document ID 2522.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---18-august.pdf
# Found 0 normalized links.
#
# Crawling (2523/3000): https://www.who.int/docs/default-source/coronaviruse/covid-19-virtual-press-conference---13-august.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��XM��6��W�\ Y��,	08���P���8m��K�~)R��D�E��xb[��H>E]����ѩ
#
# Number of tokens after preprocessing: 349
# Indexed 349 tokens for document ID 2523.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/covid-19-virtual-press-conference---13-august.pdf
# Found 0 normalized links.
#
# Crawling (2524/3000): https://www.who.int/docs/default-source/coronaviruse/covid-19-virtual-press-conference---10-august-at-12-pm-cest.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��XI��6����9�=����{���AC!���I����I��muO�s[K����ds������t�`
#
# Number of tokens after preprocessing: 368
# Indexed 368 tokens for document ID 2524.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/covid-19-virtual-press-conference---10-august-at-12-pm-cest.pdf
# Found 0 normalized links.
#
# Crawling (2525/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/who-broll-emergencies-coronavirus-press-conference-06aug2020.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.7
# %����
# 1 0 obj
# < >/Metadata 239 0 R/ViewerPreferences 240 0 R>>
# endobj
# 2 0 obj
# < >
# en
#
# Number of tokens after preprocessing: 447
# Indexed 447 tokens for document ID 2525.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/who-broll-emergencies-coronavirus-press-conference-06aug2020.pdf
# Found 0 normalized links.
#
# Crawling (2526/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-03aug2020.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# �	���誯�mq樂_�%9����L?D��t��w�3���8��
#
# Number of tokens after preprocessing: 372
# Indexed 372 tokens for document ID 2526.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference-03aug2020.pdf
# Found 0 normalized links.
#
# Crawling (2527/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---30-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˎ�6��+�.�\QK�I���tQtu�X�s7��R$%ˎ$���D6�#>��N0�s�ԠNJ
#
# Number of tokens after preprocessing: 297
# Indexed 297 tokens for document ID 2527.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---30-july.pdf
# Found 0 normalized links.
#
# Crawling (2528/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---27-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˎ�6��+�.�\Qo��$��n��(��}�n����~)R/'���ۢ��C*��ç�B��
# �N
#
# Number of tokens after preprocessing: 342
# Indexed 342 tokens for document ID 2528.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---27-july.pdf
# Found 0 normalized links.
#
# Crawling (2529/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---23-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˮ�6��+�.��HY���&��.�E�U_�i1���"��#˹�7ˢ��C*�ÿ�o��I��
#
# Number of tokens after preprocessing: 288
# Indexed 288 tokens for document ID 2529.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---23-july.pdf
# Found 0 normalized links.
#
# Crawling (2530/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---20-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Yˮ�6��+�.�T��@�y���誯մ����K�-9���$�D����G�`���uP�:)7�
#
# Number of tokens after preprocessing: 353
# Indexed 353 tokens for document ID 2530.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---20-july.pdf
# Found 0 normalized links.
#
# Crawling (2531/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---17-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# Y� �3�;?�x9iaU���!Hz�EQ\�oi��Q|�v���7#n
#
# Number of tokens after preprocessing: 364
# Indexed 364 tokens for document ID 2531.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---17-july.pdf
# Found 0 normalized links.
#
# Crawling (2532/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---13-july.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��XKo�6��W�\ ^�P�H�0 '����i�8m���� )J��l��D���G�3t���;ә�A߹�
#
# Number of tokens after preprocessing: 362
# Indexed 362 tokens for document ID 2532.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/covid-19-virtual-press-conference---13-july.pdf
# Found 0 normalized links.
#
# Crawling (2533/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/virtual-press-conference---7-july---covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# ��4YN����O��LI�lI,�z�=I���w��T�z�c
#
# Number of tokens after preprocessing: 320
# Indexed 320 tokens for document ID 2533.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/virtual-press-conference---7-july---covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2534/3000): https://www.who.int/docs/default-source/coronaviruse/virtual-press-conference---2-july---update-on-covid-19-r-d.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˊ�6��Wx_�����݆d7АE�����0w��O�J��Yn���-�J��N=l1����c��
#
# Number of tokens after preprocessing: 431
# Indexed 431 tokens for document ID 2534.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/virtual-press-conference---2-july---update-on-covid-19-r-d.pdf
# Found 0 normalized links.
#
# Crawling (2535/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/virtual-press-conference---1-july---covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��WM��8��W��Ќ%%PM������=�,�.�\��,9��ֱ�B�ؖ�Hz,ɺ���]i�;��r��0
#
# Number of tokens after preprocessing: 382
# Indexed 382 tokens for document ID 2535.
#
# Extracting links from: https://www.who.int/docs/default-source/coronaviruse/transcripts/virtual-press-conference---1-july---covid-19.pdf
# Found 0 normalized links.
#
# Crawling (2536/3000): https://www.who.int/docs/default-source/coronaviruse/transcripts/virtual-press-conference---29-june---covid-19.pdf
# Title Extracted: No Title
# Snippet Extracted: %PDF-1.5
# %äüöß
# 2 0 obj
# < >
# stream
# x��Xˎ�6��+�.�\��,	0$�hw�E�U_����M�I=���Lb=�#��:���÷IM� L.
#
# ...
# Found 217 normalized links.
#
# Crawling (2831/3000): https://www.who.int/publications/i/item/recommendations-to-member-states-to-improve-hand-hygiene-practices-to-help-prevent-the-transmission-of-the-covid-19-virus
# Title Extracted: Recommendations to Member States to improve hand hygiene practices to help prevent the transmission of the COVID-19 virus
# Snippet Extracted: Recommendations to Member States to improve hand hygiene practices to help prevent the transmission
#
# Number of tokens after preprocessing: 388
# Indexed 388 tokens for document ID 2831.
#
# Extracting links from: https://www.who.int/publications/i/item/recommendations-to-member-states-to-improve-hand-hygiene-practices-to-help-prevent-the-transmission-of-the-covid-19-virus
# Found 217 normalized links.
#
# Crawling (2832/3000): https://www.who.int/infection-prevention/campaigns/clean-hands/en
# RequestException: 404 Client Error: not found for url: https://www.who.int/infection-prevention/campaigns/clean-hands/en for URL: https://www.who.int/infection-prevention/campaigns/clean-hands/en
#
# Crawling (2833/3000): https://www.who.int/publications/m/item/save-lives-clean-your-hands-in-the-context-of-covid-19
# Title Extracted: SAVE LIVES: Clean Your Hands - in the context of COVID-19
# Snippet Extracted: SAVE LIVES: Clean Your Hands - in the context of COVID-19 Skip to main content Global Regions WHO Re
#
# Number of tokens after preprocessing: 364
# Indexed 364 tokens for document ID 2833.
#
# Extracting links from: https://www.who.int/publications/m/item/save-lives-clean-your-hands-in-the-context-of-covid-19
# Found 216 normalized links.
#
# Crawling (2834/3000): https://www.who.int/publications/i/item/immunization-as-an-essential-health-service-guiding-principles-for-immunization-activities-during-the-covid-19-pandemic-and-other-times-of-severe-disruption
# Title Extracted: Immunization as an essential health service: guiding principles for immunization activities during the COVID-19 pandemic and other times of severe disruption
# Snippet Extracted: Immunization as an essential health service: guiding principles for immunization activities during t
#
# Number of tokens after preprocessing: 382
# Indexed 382 tokens for document ID 2834.
#
# Extracting links from: https://www.who.int/publications/i/item/immunization-as-an-essential-health-service-guiding-principles-for-immunization-activities-during-the-covid-19-pandemic-and-other-times-of-severe-disruption
# Found 218 normalized links.
#
# Crawling (2835/3000): https://www.who.int/publications-detail-redirect/WHO-UHL-PHC-SP-2021.01
# Title Extracted: Building health systems resilience for universal health coverage and health security during the COVID-19 pandemic and beyond: WHO position paper
# Snippet Extracted: Building health systems resilience for universal health coverage and health security during the COVI
#
# Number of tokens after preprocessing: 462
# Indexed 462 tokens for document ID 2835.
#
# Extracting links from: https://www.who.int/publications-detail-redirect/WHO-UHL-PHC-SP-2021.01
# Found 221 normalized links.
#
# Crawling (2836/3000): https://www.who.int/publications/i/item/10665-333299
# Title Extracted: F&Q: WHO COVID-19 essential supplies forecasting tool (COVID-19-ESFT)
# Snippet Extracted: F&Q: WHO COVID-19 essential supplies forecasting tool (COVID-19-ESFT) Skip to main content Global Re
#
# Number of tokens after preprocessing: 413
# Indexed 413 tokens for document ID 2836.
#
# Extracting links from: https://www.who.int/publications/i/item/10665-333299
# Found 217 normalized links.
#
# Crawling (2837/3000): https://www.who.int/publications/m/item/list-of-priority-medical-devices-for-covid-19-case-management
# Title Extracted: List of priority medical devices for COVID-19 case management
# Snippet Extracted: List of priority medical devices for COVID-19 case management Skip to main content World Health Orga
#
# Number of tokens after preprocessing: 368
# Indexed 368 tokens for document ID 2837.
#
# Extracting links from: https://www.who.int/publications/m/item/list-of-priority-medical-devices-for-covid-19-case-management
# Found 218 normalized links.
#
# Crawling (2838/3000): https://www.who.int/publications/i/item/oxygen-sources-and-distribution-for-covid-19-treatment-centres
# Title Extracted: Oxygen sources and distribution for COVID-19 treatment centres
# Snippet Extracted: Oxygen sources and distribution for COVID-19 treatment centres Skip to main content World Health Org
#
# Number of tokens after preprocessing: 387
# Indexed 387 tokens for document ID 2838.
#
# Extracting links from: https://www.who.int/publications/i/item/oxygen-sources-and-distribution-for-covid-19-treatment-centres
# Found 217 normalized links.
#
# Crawling (2839/3000): https://www.who.int/publications/i/item/covid-19-v4-operational-support-and-logistics-disease-commodity-packages
# Title Extracted: COVID-19 v4: operational support and logistics: disease commodity packages
# Snippet Extracted: COVID-19 v4: operational support and logistics: disease commodity packages Skip to main content Worl
#
# Number of tokens after preprocessing: 343
# Indexed 343 tokens for document ID 2839.
#
# Extracting links from: https://www.who.int/publications/i/item/covid-19-v4-operational-support-and-logistics-disease-commodity-packages
# Found 216 normalized links.
#
# Crawling (2840/3000): https://www.who.int/news-room/articles-detail/who-advises-against-any-travel-and-trade-restrictions-with-rwanda-in-the-context-of-the-ongoing-marburg-virus-disease-(mvd)-outbreak
# Title Extracted: WHO advises against any travel and trade restrictions with Rwanda in the context of the ongoing Marburg virus disease (MVD) outbreak
# Snippet Extracted: WHO advises against any travel and trade restrictions with Rwanda in the context of the ongoing Marb
#
# Number of tokens after preprocessing: 665
# Indexed 665 tokens for document ID 2840.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/who-advises-against-any-travel-and-trade-restrictions-with-rwanda-in-the-context-of-the-ongoing-marburg-virus-disease-(mvd)-outbreak
# Found 220 normalized links.
#
# Crawling (2841/3000): https://www.who.int/news-room/articles-detail/who-advice-for-international-traffic-in-relation-to-the-sars-cov-2-omicron-variant
# Title Extracted: WHO advice for international traffic in relation to the SARS-CoV-2 Omicron variant (B.1.1.529)
# Snippet Extracted: WHO advice for international traffic in relation to the SARS-CoV-2 Omicron variant (B.1.1.529) Skip
#
# Number of tokens after preprocessing: 855
# Indexed 855 tokens for document ID 2841.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/who-advice-for-international-traffic-in-relation-to-the-sars-cov-2-omicron-variant
# Found 230 normalized links.
#
# Crawling (2842/3000): https://www.who.int/news-room/articles-detail/policy-and-technical-considerations-for-implementing-a-risk-based-approach-to-international-travel-in-the-context-of-covid-19
# Title Extracted: Policy and technical considerations for implementing a risk-based approach to international travel in the context of COVID-19
# Snippet Extracted: Policy and technical considerations for implementing a risk-based approach to international travel i
#
# Number of tokens after preprocessing: 501
# Indexed 501 tokens for document ID 2842.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/policy-and-technical-considerations-for-implementing-a-risk-based-approach-to-international-travel-in-the-context-of-covid-19
# Found 225 normalized links.
#
# Crawling (2843/3000): https://www.who.int/news-room/articles-detail/interim-position-paper-considerations-regarding-proof-of-covid-19-vaccination-for-international-travellers
# Title Extracted: Interim position paper: considerations regarding proof of COVID-19 vaccination for international travellers
# Snippet Extracted: Interim position paper: considerations regarding proof of COVID-19 vaccination for international tra
#
# Number of tokens after preprocessing: 1079
# Indexed 1079 tokens for document ID 2843.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/interim-position-paper-considerations-regarding-proof-of-covid-19-vaccination-for-international-travellers
# Found 241 normalized links.
#
# Crawling (2844/3000): https://www.who.int/news-room/articles-detail/considerations-for-implementing-a-risk-based-approach-to-international-travel-in-the-context-of-covid-19
# Title Extracted: Considerations for implementing a risk-based approach to international travel in the context of COVID-19
# Snippet Extracted: Considerations for implementing a risk-based approach to international travel in the context of COVI
#
# Number of tokens after preprocessing: 462
# Indexed 462 tokens for document ID 2844.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/considerations-for-implementing-a-risk-based-approach-to-international-travel-in-the-context-of-covid-19
# Found 224 normalized links.
#
# Crawling (2845/3000): https://www.who.int/news-room/articles-detail/public-health-considerations-while-resuming-international-travel
# Title Extracted: Public health considerations while resuming international travel
# Snippet Extracted: Public health considerations while resuming international travel Skip to main content Global Regions
#
# Number of tokens after preprocessing: 1996
# Indexed 1996 tokens for document ID 2845.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/public-health-considerations-while-resuming-international-travel
# Found 253 normalized links.
#
# Crawling (2846/3000): https://www.who.int/news-room/articles-detail/joint-icao-who-statement-on-covid-19
# Title Extracted: Joint ICAO-WHO Statement on COVID-19
# Snippet Extracted: Joint ICAO-WHO Statement on COVID-19 Skip to main content Global Regions WHO Regional websites Afric
#
# Number of tokens after preprocessing: 405
# Indexed 405 tokens for document ID 2846.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/joint-icao-who-statement-on-covid-19
# Found 229 normalized links.
#
# Crawling (2847/3000): https://www.who.int/news-room/articles-detail/updated-who-recommendations-for-international-traffic-in-relation-to-covid-19-outbreak
# Title Extracted: Updated WHO recommendations for international traffic in relation to COVID-19 outbreak
# Snippet Extracted: Updated WHO recommendations for international traffic in relation to COVID-19 outbreak Skip to main
#
# Number of tokens after preprocessing: 1097
# Indexed 1097 tokens for document ID 2847.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/updated-who-recommendations-for-international-traffic-in-relation-to-covid-19-outbreak
# Found 239 normalized links.
#
# Crawling (2848/3000): https://www.who.int/news-room/articles-detail/key-considerations-for-repatriation-and-quarantine-of-travellers-in-relation-to-the-outbreak-of-novel-coronavirus-2019-ncov
# Title Extracted: Key considerations for repatriation and quarantine of travellers in relation to the outbreak of novel coronavirus 2019-nCoV
# Snippet Extracted: Key considerations for repatriation and quarantine of travellers in relation to the outbreak of nove
#
# Number of tokens after preprocessing: 1239
# Indexed 1239 tokens for document ID 2848.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/key-considerations-for-repatriation-and-quarantine-of-travellers-in-relation-to-the-outbreak-of-novel-coronavirus-2019-ncov
# Found 228 normalized links.
#
# Crawling (2849/3000): https://www.who.int/news-room/articles-detail/updated-who-advice-for-international-traffic-in-relation-to-the-outbreak-of-the-novel-coronavirus-2019-ncov
# Title Extracted: Updated WHO advice for international traffic in relation to the outbreak of the novel coronavirus 2019-nCoV
# Snippet Extracted: Updated WHO advice for international traffic in relation to the outbreak of the novel coronavirus 20
#
# Number of tokens after preprocessing: 891
# Indexed 891 tokens for document ID 2849.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/updated-who-advice-for-international-traffic-in-relation-to-the-outbreak-of-the-novel-coronavirus-2019-ncov
# Found 227 normalized links.
#
# Crawling (2850/3000): https://www.who.int/news-room/articles-detail/updated-who-advice-for-international-traffic-in-relation-to-the-outbreak-of-the-novel-coronavirus-2019-ncov-24-jan
# Title Extracted: Updated WHO advice for international traffic in relation to the outbreak of the novel coronavirus 2019-nCoV
# Snippet Extracted: Updated WHO advice for international traffic in relation to the outbreak of the novel coronavirus 20
#
# Number of tokens after preprocessing: 909
# Indexed 909 tokens for document ID 2850.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/updated-who-advice-for-international-traffic-in-relation-to-the-outbreak-of-the-novel-coronavirus-2019-ncov-24-jan
# Found 229 normalized links.
#
# Crawling (2851/3000): https://www.who.int/news-room/articles-detail/who-advice-for-international-travel-and-trade-in-relation-to-the-outbreak-of-pneumonia-caused-by-a-new-coronavirus-in-china
# Title Extracted: WHO advice for international travel and trade in relation to the outbreak of pneumonia caused by a new coronavirus in China
# Snippet Extracted: WHO advice for international travel and trade in relation to the outbreak of pneumonia caused by a n
#
# Number of tokens after preprocessing: 732
# Indexed 732 tokens for document ID 2851.
#
# Extracting links from: https://www.who.int/news-room/articles-detail/who-advice-for-international-travel-and-trade-in-relation-to-the-outbreak-of-pneumonia-caused-by-a-new-coronavirus-in-china
# Found 223 normalized links.
#
# Crawling (2852/3000): https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-travel-advice-for-the-general-public
# Title Extracted: Coronavirus disease (COVID-19): Travel advice for the general public
# Snippet Extracted: Coronavirus disease (COVID-19): Travel advice for the general public Skip to main content World Heal
#
# Number of tokens after preprocessing: 871
# Indexed 871 tokens for document ID 2852.
#
# Extracting links from: https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-travel-advice-for-the-general-public
# Found 218 normalized links.
#
# Crawling (2853/3000): https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-staying-at-hotels-and-accommodation-establishments
# Title Extracted: Coronavirus disease (COVID-19): Staying at hotels and accommodation establishments
# Snippet Extracted: Coronavirus disease (COVID-19): Staying at hotels and accommodation establishments Skip to main cont
#
# Number of tokens after preprocessing: 660
# Indexed 660 tokens for document ID 2853.
#
# Extracting links from: https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-staying-at-hotels-and-accommodation-establishments
# Found 217 normalized links.
#
# Crawling (2854/3000): https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-working-in-hotels
# Title Extracted: Coronavirus disease (COVID-19): Working in hotels and other accommodation establishments
# Snippet Extracted: Coronavirus disease (COVID-19): Working in hotels and other accommodation establishments Skip to mai
#
# Number of tokens after preprocessing: 617
# Indexed 617 tokens for document ID 2854.
#
# Extracting links from: https://www.who.int/news-room/questions-and-answers/item/coronavirus-disease-covid-19-working-in-hotels
# Found 216 normalized links.
#
# Crawling (2855/3000): https://www.who.int/publications/i/item/9789240103474
# Title Extracted: Developing a model for mass gathering medical care planning: workshop report, Lyon, France, 27-28 November 2023
# Snippet Extracted: Developing a model for mass gathering medical care planning: workshop report, Lyon, France, 27-28 No
#
# Number of tokens after preprocessing: 393
# Indexed 393 tokens for document ID 2855.
#
# Extracting links from: https://www.who.int/publications/i/item/9789240103474
# Found 217 normalized links.
#
# Crawling (2856/3000): https://www.who.int/publications/i/item/B09143

# %% [markdown]
# Algorithm for checking which retrieved pages are linked

# %% [markdown]
# Query 2

# %%
import requests
from bs4 import BeautifulSoup

ret_urls = [
    "https://www.who.int/news-room/fact-sheets/detail/hiv-drug-resistance",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-11---antibiotics-covid-19",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/microbes-are-becoming-resistant-to-antibiotics",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-61---covid-19-antibiotics",
    "https://www.who.int/westernpacific/newsroom/events/world-antibiotic-awareness-week",
    "https://www.who.int/publications/who-guidelines",
    "https://www.who.int/news-room/fact-sheets/detail/multi-drug-resistant-gonorrhoea",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-99-three-things-to-keep-in-mind-when-taking-antibiotics",
    "https://www.who.int/publications/i/item/guidelines-for-malaria",
    "https://www.who.int/campaigns/world-amr-awareness-week",
    "https://www.who.int/westernpacific/activities/tackling-antimicrobial-resistance",
    "https://www.who.int/guam/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/americansamoa/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/tonga/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/vanuatu/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/wallisandfutuna/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/news-room/fact-sheets/detail/antibiotic-resistance",
    "https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance",
    "https://www.who.int/kiribati/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/tuvalu/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific"
]

for url in ret_urls:

  # URL of the webpage
  current_url = url

  # Send a request to the webpage
  response = requests.get(current_url)

  # Parse the HTML
  soup = BeautifulSoup(response.text, "html.parser")

  # Find all <a> tags
  links = soup.find_all("a")

  # Extract and print the href attributes
  for link in links:
      href = link.get("href")
      if href and "https" in href and href in ret_urls:
          print(current_url + " ---> " + href)
# Out:
# https://www.who.int/news-room/fact-sheets/detail/hiv-drug-resistance ---> https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance
# https://www.who.int/publications/who-guidelines ---> https://www.who.int/publications/i/item/guidelines-for-malaria
# https://www.who.int/publications/who-guidelines ---> https://www.who.int/publications/i/item/guidelines-for-malaria
# https://www.who.int/news-room/fact-sheets/detail/multi-drug-resistant-gonorrhoea ---> https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance
# https://www.who.int/campaigns/world-amr-awareness-week ---> https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance

# %%
import requests
from bs4 import BeautifulSoup

ret_urls = [
    "https://www.who.int/news-room/fact-sheets/detail/hiv-drug-resistance",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-11---antibiotics-covid-19",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/microbes-are-becoming-resistant-to-antibiotics",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-61---covid-19-antibiotics",
    "https://www.who.int/westernpacific/newsroom/events/world-antibiotic-awareness-week",
    "https://www.who.int/publications/who-guidelines",
    "https://www.who.int/news-room/fact-sheets/detail/multi-drug-resistant-gonorrhoea",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-99-three-things-to-keep-in-mind-when-taking-antibiotics",
    "https://www.who.int/publications/i/item/guidelines-for-malaria",
    "https://www.who.int/campaigns/world-amr-awareness-week",
    "https://www.who.int/westernpacific/activities/tackling-antimicrobial-resistance",
    "https://www.who.int/guam/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/americansamoa/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/tonga/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/vanuatu/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/wallisandfutuna/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/news-room/fact-sheets/detail/antibiotic-resistance",
    "https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance",
    "https://www.who.int/kiribati/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific",
    "https://www.who.int/tuvalu/news/feature-stories/item/combating-antimicrobial-resistance-in-the-pacific"
]

for url in ret_urls:

  # URL of the webpage
  current_url = url

  # Send a request to the webpage
  response = requests.get(current_url)

  # Parse the HTML
  soup = BeautifulSoup(response.text, "html.parser")

  # Find all <a> tags
  links = soup.find_all("a")

  # Extract and print the href attributes
  for link in links:
      href = link.get("href")
      if href and "https" in href and href in ret_urls:
          print(current_url + " : " + "[" + href + "]")
# Out:
# https://www.who.int/news-room/fact-sheets/detail/hiv-drug-resistance : [https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance]
# https://www.who.int/publications/who-guidelines : [https://www.who.int/publications/i/item/guidelines-for-malaria]
# https://www.who.int/publications/who-guidelines : [https://www.who.int/publications/i/item/guidelines-for-malaria]
# https://www.who.int/news-room/fact-sheets/detail/multi-drug-resistant-gonorrhoea : [https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance]
# https://www.who.int/campaigns/world-amr-awareness-week : [https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance]

# %% [markdown]
# Query 1

# %%
import requests
from bs4 import BeautifulSoup

ret_urls = [
    "https://www.who.int/news-room/fact-sheets/detail/diabetes",
    "https://www.who.int/news-room/fact-sheets/detail/lung-cancer",
    "https://www.who.int/news-room/fact-sheets/detail/schistosomiasis",
    "https://www.who.int/news-room/fact-sheets/detail/hepatitis-c",
    "https://www.who.int/news-room/fact-sheets/detail/depression",
    "https://www.who.int/news-room/fact-sheets/detail/human-papilloma-virus-and-cancer",
    "https://www.who.int/news-room/fact-sheets/detail/cancer",
    "https://www.who.int/westernpacific/activities/improving-access-to-prevention-testing-and-treatment-for-hepatitis",
    "https://www.who.int/news-room/fact-sheets/detail/colorectal-cancer",
    "https://www.who.int/publications/i/item/9789240096745",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-46---diabetes-covid-19",
    "https://www.who.int/news-room/fact-sheets/detail/endometriosis",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-68-covid-19-update-on-long-covid",
    "https://www.who.int/news-room/fact-sheets/detail/mycetoma",
    "https://www.who.int/news-room/fact-sheets/detail/tuberculosis",
    "https://www.who.int/news-room/fact-sheets/detail/leprosy",
    "https://www.who.int/news/item/08-01-2025-who-prequalifies-diagnostic-test-to-support-safer-administration-of-p.-vivax-malaria-treatments",
    "https://www.who.int/news-room/fact-sheets/detail/ebola-virus-disease",
    "https://www.who.int/news/item/23-04-2024-promising-patient-friendly-oral-drug-against-visceral-leishmaniasis-enters-phase-ii-clinical-trial-in-ethiopia",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-37---treatment-and-care-at-home"
]

for url in ret_urls:

  # URL of the webpage
  current_url = url

  # Send a request to the webpage
  response = requests.get(current_url)

  # Parse the HTML
  soup = BeautifulSoup(response.text, "html.parser")

  # Find all <a> tags
  links = soup.find_all("a")

  # Extract and print the href attributes
  for link in links:
      href = link.get("href")
      if href and "https" in href and href in ret_urls:
          print(current_url + " ---> " + href)
# Out:
# https://www.who.int/news-room/fact-sheets/detail/lung-cancer ---> https://www.who.int/news-room/fact-sheets/detail/cancer
# https://www.who.int/news-room/fact-sheets/detail/cancer ---> https://www.who.int/news-room/fact-sheets/detail/colorectal-cancer
# https://www.who.int/news-room/fact-sheets/detail/cancer ---> https://www.who.int/news-room/fact-sheets/detail/lung-cancer
# https://www.who.int/news-room/fact-sheets/detail/colorectal-cancer ---> https://www.who.int/news-room/fact-sheets/detail/cancer
# https://www.who.int/news-room/fact-sheets/detail/colorectal-cancer ---> https://www.who.int/news-room/fact-sheets/detail/lung-cancer
# https://www.who.int/news-room/fact-sheets/detail/mycetoma ---> https://www.who.int/news-room/fact-sheets/detail/leprosy
# https://www.who.int/news-room/fact-sheets/detail/leprosy ---> https://www.who.int/news-room/fact-sheets/detail/mycetoma

# %% [markdown]
# **Query** 2

# %%
import requests
from bs4 import BeautifulSoup

ret_urls = [
    "https://www.who.int/teams/health-workforce/PHEworkforce",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/hepatitis-outbreak-in-children",
    "https://www.who.int/publications/b",
    "https://www.who.int/malaysia/emergencies/covid-19-in-malaysia/information",
    "https://www.who.int/publications/i/item/9789240090743",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-71---covid-19-vaccines-and-children",
    "https://www.who.int/emergencies/operations",
    "https://www.who.int/activities/measuring-the-effectiveness-and-impact-of-public-health-and-social-measures",
    "https://www.who.int/westernpacific/activities/communicating-risk-in-public-health-emergencies",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/public-health-emergency-of-international-concern",
    "https://www.who.int/mongolia/multi-media/item/live-life-safely--trains-and-public-transport",
    "https://www.who.int/westernpacific/our-work/resources/publications",
    "https://www.who.int/westernpacific/publications",
    "https://www.who.int/westernpacific/activities/detecting-and-assessing-emergency-health-threats",
    "https://www.who.int/emergencies/diseases/novel-coronavirus-2019/media-resources/science-in-5/episode-43---pregnancy-covid-19",
    "https://www.who.int/publications/i/9789240081277",
    "https://www.who.int/about/policies/publishing/open-access",
    "https://www.who.int/westernpacific/publications/i",
    "https://www.who.int/americansamoa/publications",
    "https://www.who.int/brunei/publications-hub"
]

for url in ret_urls:

  # URL of the webpage
  current_url = url

  # Send a request to the webpage
  response = requests.get(current_url)

  # Parse the HTML
  soup = BeautifulSoup(response.text, "html.parser")

  # Find all <a> tags
  links = soup.find_all("a")

  # Extract and print the href attributes
  for link in links:
      href = link.get("href")
      if href and "https" in href and href in ret_urls:
          print(current_url + " ---> " + href)
# Out:
# https://www.who.int/westernpacific/activities/communicating-risk-in-public-health-emergencies ---> https://www.who.int/westernpacific/activities/communicating-risk-in-public-health-emergencies

# %% [markdown]
# Query 3

# %%
import requests
from bs4 import BeautifulSoup

ret_urls = [
    "https://www.who.int/campaigns/world-mental-health-day",
    "https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response",
    "https://www.who.int/news-room/fact-sheets/detail/mental-health-at-work",
    "https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies",
    "https://www.who.int/westernpacific/activities/promoting-mental-health",
    "https://www.who.int/china/news/feature-stories/detail/covid-19-sounding-the-alarm-again-that-mental-health-intervention-is-an-indispensable-health-service",
    "https://www.who.int/pitcairnislands/emergencies",
    "https://www.who.int/tokelau/emergencies",
    "https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies",
    "https://www.who.int/emergencies/operations",
    "https://www.who.int/westernpacific/activities/strengthening-government-action-on-mental-health",
    "https://www.who.int/westernpacific/activities/developing-community-based-mental-health-services",
    "https://www.who.int/fiji/publications-detail/RS-2003-GE-44-TON",
    "https://www.who.int/teams/health-workforce/PHEworkforce",
    "https://www.who.int/westernpacific/about/how-we-work/programmes/who-health-emergencies-programme",
    "https://www.who.int/news-room/fact-sheets/detail/occupational-health--health-workers",
    "https://www.who.int/news-room/fact-sheets/detail/mental-health-and-forced-displacement",
    "https://www.who.int/news-room/fact-sheets/detail/health-literacy",
    "https://www.who.int/malaysia/news/detail/12-09-2024-singapore-contributes-to-regional-health-emergency-readiness-through-achieving-emergency-medical-team-classification",
    "https://www.who.int/singapore/news/detail/12-09-2024-singapore-contributes-to-regional-health-emergency-readiness-through-achieving-emergency-medical-team-classification"
]
for url in ret_urls:
  # URL of the webpage
  current_url = url
  # Send a request to the webpage
  response = requests.get(current_url)
  # Parse the HTML
  soup = BeautifulSoup(response.text, "html.parser")
  # Find all <a> tags
  links = soup.find_all("a")
  # Extract and print the href attributes
  for link in links:
      href = link.get("href")
      if href and "https" in href and href in ret_urls:
        print(current_url + " : " + "[" + href + "]")
# Out:
# https://www.who.int/campaigns/world-mental-health-day : [https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response]
# https://www.who.int/campaigns/world-mental-health-day : [https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response : [https://www.who.int/news-room/fact-sheets/detail/mental-health-and-forced-displacement]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response : [https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-at-work : [https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-at-work : [https://www.who.int/news-room/fact-sheets/detail/occupational-health--health-workers]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies : [https://www.who.int/news-room/fact-sheets/detail/mental-health-and-forced-displacement]
# https://www.who.int/westernpacific/activities/promoting-mental-health : [https://www.who.int/campaigns/world-mental-health-day]
# https://www.who.int/westernpacific/activities/promoting-mental-health : [https://www.who.int/westernpacific/activities/strengthening-government-action-on-mental-health]
# https://www.who.int/westernpacific/activities/promoting-mental-health : [https://www.who.int/westernpacific/activities/developing-community-based-mental-health-services]
# https://www.who.int/westernpacific/activities/promoting-mental-health : [https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies]
# https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies : [https://www.who.int/westernpacific/activities/strengthening-government-action-on-mental-health]
# https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies : [https://www.who.int/westernpacific/activities/developing-community-based-mental-health-services]
# https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies : [https://www.who.int/westernpacific/activities/promoting-mental-health]
# https://www.who.int/westernpacific/activities/developing-community-based-mental-health-services : [https://www.who.int/westernpacific/activities/protecting-mental-health-during-emergencies]
# https://www.who.int/westernpacific/activities/developing-community-based-mental-health-services : [https://www.who.int/westernpacific/activities/strengthening-government-action-on-mental-health]
# https://www.who.int/news-room/fact-sheets/detail/mental-health-and-forced-displacement : [https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies]

# %%
def calculate_new_pagerank(current_ranks, links):
    new_ranks = {}

    # Calculate new PageRank for each page
    for page in current_ranks:
        # Find who links to this page
        incoming_links = [p for p, outgoing in links.items() if page in outgoing]

        # Sum up PageRank contributions
        rank_sum = 0
        for source_page in incoming_links:
            # Get number of outgoing links from source page
            num_outgoing = len(links[source_page])
            # Add contribution from this source page
            rank_sum += current_ranks[source_page] / num_outgoing

        new_ranks[page] = rank_sum

    return new_ranks

def print_ranks(ranks, iteration):
    print(f"\nPageRank values after iteration {iteration}:")
    print("-" * 35)
    print("Page  |  PageRank Value")
    print("-" * 35)
    for page, rank in ranks.items():
        print(f"  {page}   |     {rank:.3f}")
    print("-" * 35)

# Define the web structure
A = 'https://www.who.int/news-room/fact-sheets/detail/hiv-drug-resistance'
B = 'https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance'
C = 'https://www.who.int/publications/who-guidelines'
D = 'https://www.who.int/publications/i/item/guidelines-for-malaria'
E = 'https://www.who.int/news-room/fact-sheets/detail/multi-drug-resistant-gonorrhoea'
F = 'https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance'
G = 'https://www.who.int/campaigns/world-mental-health-day'
H = 'https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response'
I = 'https://www.who.int/news-room/fact-sheets/detail/mental-health-in-emergencies'
J = 'https://www.who.int/westernpacific/activities/promoting-mental-health'
links = {
    'A' : ['B'],
    'C' : ['D'],
    'E' : ['F'],
    'G' : ['H', 'I'],
    'J' : ['G']

}

# Initialize PageRank values (1/10 for each page)
pages = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
current_ranks = {page: 1/10 for page in pages}

print("Web structure:")
for page, outlinks in links.items():
    print(f"Page {page} links to: {', '.join(outlinks)}")

# Print initial values
print("\nInitial PageRank Values:")
print_ranks(current_ranks, 0)

# First iteration
first_iteration = calculate_new_pagerank(current_ranks, links)
print_ranks(first_iteration, 1)

# Second iteration
second_iteration = calculate_new_pagerank(first_iteration, links)
print_ranks(second_iteration, 2)

# Find highest PageRank after second iteration
highest_page = max(second_iteration.items(), key=lambda x: x[1])
print(f"\nHighest PageRank after second iteration:")
print(f"Page {highest_page[0]} with PageRank value of {highest_page[1]:.3f}")
# Out:
# Web structure:
# Page A links to: B
# Page C links to: D
# Page E links to: F
# Page G links to: H, I
# Page J links to: G
#
# Initial PageRank Values:
#
# PageRank values after iteration 0:
# -----------------------------------
# Page  |  PageRank Value
# -----------------------------------
#   A   |     0.100
#   B   |     0.100
#   C   |     0.100
#   D   |     0.100
#   E   |     0.100
#   F   |     0.100
#   G   |     0.100
#   H   |     0.100
#   I   |     0.100
#   J   |     0.100
# -----------------------------------
#
# PageRank values after iteration 1:
# -----------------------------------
# Page  |  PageRank Value
# -----------------------------------
#   A   |     0.000
#   B   |     0.100
#   C   |     0.000
#   D   |     0.100
#   E   |     0.000
#   F   |     0.100
#   G   |     0.100
#   H   |     0.050
#   I   |     0.050
#   J   |     0.000
# -----------------------------------
#
# PageRank values after iteration 2:
# -----------------------------------
# Page  |  PageRank Value
# -----------------------------------
#   A   |     0.000
#   B   |     0.000
#   C   |     0.000
#   D   |     0.000
#   E   |     0.000
#   F   |     0.000
#   G   |     0.000
#   H   |     0.050
#   I   |     0.050
#   J   |     0.000
# -----------------------------------
#
# Highest PageRank after second iteration:
# Page H with PageRank value of 0.050
